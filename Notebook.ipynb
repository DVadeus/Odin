# %% [markdown]
# # Fases

# %% [markdown]
# ## 1 Core Operacional
#
# - ThirdParty
# - Product
# - Inventory
# - Purchase
# - Quote
# - WorkOrder
# - Production
# - Delivery
# - Siigo Integration

# %% [markdown]
# ## 2 Planeación Producción
#
# - tablero planta
# - cola prioridades
# - métricas
# - tiempos estimados
# - KPIs

# %% [markdown]
# ## 3 Manufactura avanzada
#
# - historial troquel
# - reutilización
# - analytics
# - costos reales
# - forecasting

# %% [markdown]
# # TODO

# %% [markdown]
# ### .env
#
# Debo usar diferentes .env para cada etapa de desarrollo
#
# - .env.local
# - .env.test
# - .env.production
#
# al igual que Docker Compose para cada ambiente
#
# - docker-compose.local.yml
# - docker-compose.test.yml
# - docker-compose.prod.yml
